# %%
import numpy as np
import pandas as pd
import statistics

# %% [markdown]
# ### Reading data set into python

# %%
dta=pd.read_excel('Dataset_w6 (1).xlsx')
dta
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %% [markdown]
# ### calcuating count of countries

# %%
dta['country'].count
# Out:
# <bound method Series.count of 0                             Afghanistan
# 1                                 Albania
# 2                                 Algeria
# 3                                  Angola
# 4                     Antigua and Barbuda
#                       ...
# 191    Venezuela (Bolivarian Republic of)
# 192                              Viet Nam
# 193                                 Yemen
# 194                                Zambia
# 195                              Zimbabwe
# Name: country, Length: 196, dtype: object>

# %% [markdown]
# ### count of countries wrt to region

# %%
dta['Region'].value_counts()
# Out:
# WesternAsia          18
# EasternAfrica        17
# Caribbean            16
# WesternAfrica        15
# SouthAmerica         12
# SouthernEurope       12
# South-easternAsia    11
# EasternEurope        10
# NorthernEurope       10
# SouthernAsia          9
# MiddleAfrica          9
# CentralAmerica        8
# WesternEurope         7
# EasternAsia           7
# SouthernAfrica        5
# Polynesia             5
# NorthernAfrica        5
# Melanesia             5
# CentralAsia           5
# NorthernAmerica       4
# Micronesia            4
# Oceania               2
# Name: Region, dtype: int64

# %% [markdown]
# ### Region with highest GDP

# %%
dta1=dta[['Region','GDP per capita (current US$)']].groupby('Region').mean()

# %%
print(dta1)
# Out:
#                    GDP per capita (current US$)
# Region
# Caribbean                          15135.562500
# CentralAmerica                      6348.137500
# CentralAsia                         4329.880000
# EasternAfrica                       2088.852941
# EasternAsia                        27967.614286
# EasternEurope                       9292.490000
# Melanesia                           9261.960000
# Micronesia                          5008.300000
# MiddleAfrica                        3928.833333
# NorthernAfrica                      3934.960000
# NorthernAmerica                    57659.000000
# NorthernEurope                     42098.220000
# Oceania                            44823.250000
# Polynesia                           8686.520000
# South-easternAsia                  10299.027273
# SouthAmerica                        8499.775000
# SouthernAfrica                      4191.900000
# SouthernAsia                        2968.400000
# ...

# %%
dta1['GDP per capita (current US$)'].idxmax()
# Out:
# 'NorthernAmerica'

# %% [markdown]
# NorthernAmerica is the region with  highest GDP

# %% [markdown]
# ### Region with highest international trade

# %%
dta2=dta[['Region','International trade: Imports (million US$)']].groupby('Region').mean()

# %%
print(dta2)
# Out:
#                    International trade: Imports (million US$)
# Region
# Caribbean                                         3057.312500
# CentralAmerica                                   57031.500000
# CentralAsia                                      12063.400000
# EasternAfrica                                     4726.176471
# EasternAsia                                     451995.000000
# EasternEurope                                    85243.900000
# Melanesia                                         2896.400000
# Micronesia                                          99.000000
# MiddleAfrica                                      4381.222222
# NorthernAfrica                                   35034.400000
# NorthernAmerica                                 663552.250000
# NorthernEurope                                  113407.200000
# Oceania                                         112914.500000
# Polynesia                                          432.000000
# ...

# %%
dta2['International trade: Imports (million US$)'].idxmax()
# Out:
# 'NorthernAmerica'

# %% [markdown]
# NorthernAmerica has highest International trade

# %% [markdown]
# ### Region with consistent GDP

# %%
dta4=dta.groupby('Region').var()

# %%
dta4
# Out:
#                    Surface area (km2)  Population in thousands (2017)  \
# Region
# Caribbean                8.353647e+08                    1.895925e+07
# CentralAmerica           4.480946e+11                    1.892164e+09
# CentralAsia              1.179496e+12                    1.238364e+08
# EasternAfrica            1.423489e+11                    7.349693e+08
# EasternAsia              1.250060e+13                    2.715476e+11
# EasternEurope            2.861112e+13                    1.819253e+09
# Melanesia                3.934911e+10                    1.203126e+07
# Micronesia               6.472200e+04                    1.977583e+03
# MiddleAfrica             5.807653e+11                    6.736192e+08
# NorthernAfrica           8.206261e+11                    1.315526e+09
# NorthernAmerica          2.675199e+13                    2.466636e+10
# NorthernEurope           2.443277e+10                    3.918786e+08
# ...

# %%
dta4['GDP per capita (current US$)'].idxmin()
# Out:
# 'WesternAfrica'

# %% [markdown]
# WesternAfrica is the country with most consistent GDP
